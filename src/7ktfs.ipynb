# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("../data/20181106_APBvs7kTF_correlation.csv",index_col="Gene")

# %%
df.iloc[:20]
# Out:
#           Correlation_Coefficiency
# Gene
# APOBEC3B                  1.000000
# APOBEC3A                  0.893081
# APOBEC3D                  0.613022
# APOBEC3C                  0.373329
# APOBEC3F                  0.362085
# FOSL1                     0.346710
# MAFF                      0.311360
# DRAP1                     0.285418
# NFE2L3                    0.256284
# ZBTB38                    0.251366
# NFKB2                     0.247330
# RUNX2                     0.244427
# ELK3                      0.242611
# TFAP2C                    0.234121
# IRF1                      0.232282
# VDR                       0.230301
# MITF                      0.229316
# KLF6                      0.225224
# APOBEC3G                  0.224446
# ETV4                      0.224164
